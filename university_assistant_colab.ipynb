# %% [markdown]
# # AI University Assistant - RAG Pipeline Notebook
# This notebook demonstrates loading PDFs, creating embeddings using HuggingFace, and testing RAG outputs with Groq API.

# %%
# !pip install langchain langchain-community langchain-groq sentence-transformers faiss-cpu pypdf python-dotenv
